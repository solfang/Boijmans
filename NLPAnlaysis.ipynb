# %%
import pandas as pd
from ast import literal_eval
import seaborn as sns

from tqdm import tqdm
tqdm.pandas()  # for pandas progress_apply()

import re
from bertopic import BERTopic
from hdbscan import HDBSCAN
from umap import UMAP
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
import string
punctuation = string.punctuation + "•’"

# %% [markdown]
# **to use 'en_core_web_sm' run:**
# `python -m spacy download en_core_web_sm`

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# Required for the sentiment analysis (can comment out if not needed)
# `pip install spacytextblob`
# `pip install spacy[transformers]`

# %%
from spacytextblob.spacytextblob import SpacyTextBlob # required to run  nlp.add_pipe('spacytextblob')
nlp.add_pipe('spacytextblob')

# %%
sns.set(rc={'figure.figsize': (20, 6)})
sns.set(font_scale=1.5)

# %%
# read df
converters = {"album_images": literal_eval, "hashtags": literal_eval, "comments_flat": literal_eval,
              "timestamp": pd.to_datetime, "image_label": literal_eval}
df = pd.read_csv("DepotBoijmans.csv", converters=converters, index_col="timestamp")
df
# Out:
#                                                              shortcode  \
# timestamp
# 2020-01-01 14:34:39  postaf1cd604a7f645109218b27f109b3fea1b6720faee...
# 2020-01-03 12:30:28  post3b75c80595d506a8d022c1751aa23c83faf0b8ebb9...
# 2020-01-03 14:53:16  post6a8292ba8694c8073b2fb6a4bad92a97afcdf023d7...
# 2020-01-03 21:35:55  post7bfd20688f33426e1e5eaf767124178580f10b0182...
# 2020-01-04 01:35:44  post8135f43902591b4a073e72b39531776c7cdf006b7d...
# ...                                                                ...
# 2021-12-31 16:02:27  post7c1c3c1db2129fe79a0226bbfe1356229e866a16d0...
# 2021-12-31 18:47:37  post9d57b38dcb71de96f81340a67516acf4248f33ddf4...
# 2021-12-31 19:15:19  post464bb11a852053bb173d88a348cab76b7cbcd2e672...
# 2021-12-31 19:21:02  post52587efabf903274d65d9108c20c43b50a2de85539...
# 2021-12-31 19:27:13  post6d64dc8a124215062c02c7828e4bfc37153106cdf9...
#
#                                                         owner_username  \
# timestamp
# 2020-01-01 14:34:39  user8392bf148647eddd2fc3e3edf65add3268736213ed...
# 2020-01-03 12:30:28  userc0337aa6f789320dd6040cefdd4261e0c8f98ed61c...
# 2020-01-03 14:53:16  userf493e1a39259129fa2658ec2474b4e09689b2ba265...
# 2020-01-03 21:35:55  usereb1e6224cc3371fe9262695619be88cfa23095ea4e...
# 2020-01-04 01:35:44  user59216ece376ad65994c9ccab8edb8b681c82e4ea41...
# ...                                                                ...
# 2021-12-31 16:02:27  userd6740396be33cad354155dda1a167b51ae1170d6f9...
# 2021-12-31 18:47:37  user0982559bde8b51afab37ecbb54dc2c29a77cf56190...
# 2021-12-31 19:15:19  user5bbe3e9245c38f2e8cc6e672213fedfdd5534c6968...
# 2021-12-31 19:21:02  user4622de33452f1db17290f13143765b249548921c77...
# 2021-12-31 19:27:13  usere65caa9cd0fabb7f6c766c17a696889ee561437b76...
#
#                       MicroRole MacroRole  likes  comment_count  \
# timestamp
# 2020-01-01 14:34:39  Individual   Private     27              2
# 2020-01-03 12:30:28  Individual   Private     11              0
# 2020-01-03 14:53:16  Enterprise   Private     40              0
# 2020-01-03 21:35:55  Individual   Private      9              1
# 2020-01-04 01:35:44  Individual   Private    309              6
# ...                         ...       ...    ...            ...
# 2021-12-31 16:02:27  Individual   Private     37              5
# 2021-12-31 18:47:37  Individual   Private     39              0
# 2021-12-31 19:15:19  Individual   Private     14              0
# 2021-12-31 19:21:02  Individual   Private      2              0
# 2021-12-31 19:27:13  Individual   Private     25              1
#
#                                           location  owner_followercount  \
# timestamp
# 2020-01-01 14:34:39                            NaN                   93
# 2020-01-03 12:30:28  Museum Boijmans Van Beuningen                  176
# 2020-01-03 14:53:16                        Westkop                  960
# 2020-01-03 21:35:55                            NaN                   43
# 2020-01-04 01:35:44  Museum Boijmans Van Beuningen                 4280
# ...                                            ...                  ...
# 2021-12-31 16:02:27              Rotterdam Centrum                  190
# 2021-12-31 18:47:37         Rotterdam, Netherlands                  998
# 2021-12-31 19:15:19   Depot Boijmans van Beuningen                  345
# 2021-12-31 19:21:02                            NaN                   97
# 2021-12-31 19:27:13   Depot Boijmans van Beuningen                  167
#
#                      interactions  \
# timestamp
# 2020-01-01 14:34:39            29
# 2020-01-03 12:30:28            11
# 2020-01-03 14:53:16            40
# 2020-01-03 21:35:55            10
# 2020-01-04 01:35:44           315
# ...                           ...
# 2021-12-31 16:02:27            42
# 2021-12-31 18:47:37            39
# 2021-12-31 19:15:19            14
# 2021-12-31 19:21:02             2
# 2021-12-31 19:27:13            26
#
#                                                             caption_en  \
# timestamp
# 2020-01-01 14:34:39  #rotterdam#nederland#netherlands #holland#depo...
# 2020-01-03 12:30:28  #depotBoijmans #underconstruction #fascinating...
# 2020-01-03 14:53:16  Start the first weekend of the new year right ...
# 2020-01-03 21:35:55            #depot#museum#boijmans@user#january2020
# 2020-01-04 01:35:44  #Depot #boijmansvanbeuningen #museum #undercon...
# ...                                                                ...
# 2021-12-31 16:02:27  Rotterdam's new ICON #skylinerotterdam #bearde...
# 2021-12-31 18:47:37  Especially photos of the village where I live,...
# 2021-12-31 19:15:19  #batiment #architectural #musee #museum #build...
# 2021-12-31 19:21:02       #depotboijmansvanbeuningen 31 december 2021
# 2021-12-31 19:27:13  A colourful 2022!!! Happy New Year!\nGelukkig ...
#
#                                                               hashtags  \
# timestamp
# 2020-01-01 14:34:39  [rotterdam, nederland, netherlands, holland, d...
# 2020-01-03 12:30:28  [depotBoijmans, underconstruction, fascinating...
# 2020-01-03 14:53:16  [westkop, rotterdam, museumpark, bier, weekend...
# 2020-01-03 21:35:55             [depot, museum, boijmans, january2020]
# 2020-01-04 01:35:44  [Depot, boijmansvanbeuningen, museum, undercon...
# ...                                                                ...
# 2021-12-31 16:02:27  [depot, depotboijmansvanbeuningen, rotterdam, ...
# 2021-12-31 18:47:37  [rotterdam, rottergram, rottergram010, rotterd...
# 2021-12-31 19:15:19  [batiment, architectural, musee, museum, build...
# 2021-12-31 19:21:02                        [depotboijmansvanbeuningen]
# 2021-12-31 19:27:13  [acolourfulnewyear, 2022, happynewyear, bonnea...
#
#                                                             comment_en  \
# timestamp
# 2020-01-01 14:34:39  ['great photo henk, Happy new year to you and ...
# 2020-01-03 12:30:28                                                 []
# 2020-01-03 14:53:16                                                 []
# 2020-01-03 21:35:55  ['Wij waren ook in Rotterdam, hadden we nog ku...
# 2020-01-04 01:35:44  ['⚓️😍', '😃 @user', 'Nice fine contrast on this...
# ...                                                                ...
# 2021-12-31 16:02:27  ['Mooi, wij moeten er binnenkort ook maar eens...
# 2021-12-31 18:47:37                                                 []
# 2021-12-31 19:15:19                                                 []
# 2021-12-31 19:21:02                                                 []
# 2021-12-31 19:27:13                                             ['U2']
#
#                      num_images                                    image_label
# timestamp
# 2020-01-01 14:34:39           1                                      [Outside]
# 2020-01-03 12:30:28           5           [Outside, Outside, Outside, Outside]
# 2020-01-03 14:53:16           1                                         [Misc]
# 2020-01-03 21:35:55           1                                         [Misc]
# 2020-01-04 01:35:44           1                                      [Outside]
# ...                         ...                                            ...
# 2021-12-31 16:02:27           3                             [Outside, Outside]
# 2021-12-31 18:47:37           1                                         [Misc]
# 2021-12-31 19:15:19           1                                      [Outside]
# 2021-12-31 19:21:02           1                                      [Outside]
# 2021-12-31 19:27:13           6  [Outside, Outside, Outside, Outside, Outside]
#
# [8228 rows x 14 columns]

# %% [markdown]
# # Dataset notes
# The data was originally scraped from Instagram using a third-party scraper from rapidapi.com.
# The dataset was pre-processed and cleaned in the following ways (not included in this notebook because they're manual or time-consuming):
# - shortcode/owner_username: has been anonymized (hashed) for the publication of this dataset
# - MicroRole/MacroRole: 107 'high-interaction' users were reviewed by two researchers (pre-anonymization) and categorized into 6 roles (see the paper for more details):
#     - Public side: Affiliated Enterprise, Depot Boijmans Designer, Public Institution
#     - Private side: Enterprise, Individual, Private Tourism Outlet
#     All other users were classified as 'Individual'
# - caption_en/comment_en: posts caption and comments was translated into English using https://pypi.org/project/deep-translator/ (not included in this notebook because it's time-consuming)
# - image_label:  was set as the result of clustering+manual post-processing of clusters as well as labeling, see below in this notebook

# %% [markdown]
# # Topic Modeling with Bertopic

# %% [markdown]
# Some pre-processing. BERTopic works on natural language and does not need lemmatization etc. Though we found that removing mentions and stopwords improved the topic coherence.

# %%
def remove_stopwords(words):
    return [word for word in words if word not in stop_words]

def remove_mentions(text):
    text = re.sub(r"@(\w+)", "", text)
    return text

def bertopic_topics_to_df(model, max_topics=10):
    """
    :param model: BERTopic model
    :param max_topics: topic modeling topics
    :return: topic modeling topics as dataframe
    """
    columns = {}
    for i in range(max_topics):
        topic = model.get_topic(i)
        if topic:
            column_data = list(map(lambda t: t[0], topic))
            columns[i] = column_data

    return pd.DataFrame(columns)

def format_bracket(val1, val2, percent=False, round_to=1, stdev=False):
    print(val1,val2)
    """
    Formats as 'val1 (val2)' or 'val1 (val2%)'
    """
    if round_to == 0:
        round_to = None
    if percent:
        str2 = " ({:.1%})"
    elif stdev:
        str2 = " (±{:,})"
        val2 = round(val2, round_to)
    else:
        str2 = " ({:,})"
        val2 = round(val2, round_to)

    return "{:,}".format(round(val1, round_to)) + str2.format(val2)

def split_by_trailing_hashtags(text, punctuation_string=""):
    """
    Splits text into two parts:
    head: text including hashtags in the text
    tail: all trailing hashtags
    :param text:
    :param punctuation_string: characters in this string will be ignored when splitting
    e.g. "text .#bla #blub" will be split into "text" ".#bla #blub" (note the 'lost' space in the middle, have to add that when merging back)
    :return:
    """
    tail = []

    arr = text.split(" ")
    while len(arr) > 0:
        if arr[-1].startswith("#") or arr[-1].startswith("@") or arr[-1] in punctuation_string:
            tail = [arr[-1]] + tail
            arr = arr[:-1]
        else:
            break
    head = " ".join(arr)
    tail = " ".join(tail)

    return head, tail

df["caption_en"] = df["caption_en"].fillna("")
df["caption_en_head"] = df["caption_en"].apply(lambda x: split_by_trailing_hashtags(x)[0])

df["caption_en_nostopwords"] = df["caption_en"].apply(lambda s: " ".join(remove_stopwords(s.lower().split(" "))))
df["caption_en_head_nostopwords"] = df["caption_en_head"].apply(
    lambda s: " ".join(remove_stopwords(s.lower().split(" "))))

micro_roles = list(df["MicroRole"].unique())

# %% [markdown]
# Quick topic model of the whole dataset

# %%
model = BERTopic(verbose=True)
texts = df["caption_en"]
topics, probabilities = model.fit_transform(texts)
model.visualize_topics()
# Out:
# Batches:   0%|          | 0/258 [00:00<?, ?it/s]
# 2022-12-26 16:16:40,308 - BERTopic - Transformed documents to Embeddings
# 2022-12-26 16:16:52,136 - BERTopic - Reduced dimensionality with UMAP
# 2022-12-26 16:16:52,497 - BERTopic - Clustered UMAP embeddings with HDBSCAN
# <div>                            <div id="a19ec9e4-e475-4082-91c9-011ad1fd6a07" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a19ec9e4-e475-4082-91c9-011ad1fd6a07")) {                    Plotly.newPlot(                        "a19ec9e4-e475-4082-91c9-011ad1fd6a07",                        [{"customdata":[[0,"caesar | caesardonna | caesaruomo | welcomes | donna",518],[1,"mirror | reflection | reflections | wall | mirrors",275],[2,"storage | collection | first | the | of",268],[3,"eurovision | countdown | openup | song | esc2021",217],[4,"depotboijmansvanbeuningen | rotterdam | rotterdamdepotboijmansvanbeuningen | nofilter | gemeenterotterdam",157],[5,"depotboijmansvanbeuningen | hans | depotgebouwboijmansvanbeuningen | usermehra1238 | thefairestofthemall",91],[6,"user | photos | by | work | happy",83],[7,"silver | opening | silveropening | zilverenopening | preview",81],[8,"building | what | beautiful | buildings | amazing",74],[9,"depot | impression | goes | night | under",72],[10,"museumpark | depotboijmansvanbeuningen | museumbooijmansvanbeuningen | rotterdam | museumboijmansvanbeuningen",67],[11,"beuningen | van | boijmans | depot | rotterdam",65],[12,"skaters | skateboard | skate | skateboarding | petition",62],[13,"pot | de | posset | nickname | rotterdam",60],[14,"boijmansdepot | collectieopzuid | platform | bling | boijmansvanbeuningen",60],[15,"boijmansvanbeuningen | bocajpictures | crossroads | rotterdam | depot",52],[16,"cityphotography | rottergram | rotterdamcity | rotterdam010 | rotterdaminthepicture",52],[17,"van | beuningen | boijmans | depot | kacarov",51],[18,"insiderotterdam | rottahistorica010 | komieuitrotterdamdan | gersmagazine | rotterdamhotspots",51],[19,"kunstopslag | museum | instagrannyfotografeert | boijmans | beuningen",50],[20,"day | rotterdam | asset | jonghs | m4",50],[21,"bag | shopping | agaat | susanbijl | june",50],[22,"icon | new | gers | icons | 010",49],[23,"wow | nice | cloud | manage | see",49],[24,"museum | beuningen | boijmans | royal | van",48],[25,"architecturephotography | gafvanbaalen | boijmansmuseum | architecture | winymaas",48],[26,"coronawalk | dailywalk | aphotoaday | ilovemycity | smartphonephotography",47],[27,"skyline | skylinerotterdam | zalmhaven | tower | zalmhaventoren",46],[28,"storytelling | tourguide | something | day | mijnstadjouwstadonzestad",46],[29,"boymansvanbeuningen | boymans | depotboymansvanbeuningen | boymansvanbeuningenmuseum | iphone11pro",45],[30,"mirrors | mirror | kunstpark | 1664 | stories",45],[31,"mirror | wall | hoff | mirrors | concise",45],[32,"light | lights | lightshow | colours | night",43],[33,"boijmansvanbeuningen | depot | 6995 | howlsmovingcastle | vc",42],[34,"arkiromantix | architecturehunter | rawarchitecture | lookinguparchitecture | welcometoreflections",40],[35,"depot | rotterdam | recommended | depotdepotboijmansvanbeuningenrotterdam010 | maefinallyout",39],[36,"mom | hey | 20202021 | namjoon | werf",38],[37,"museum | beuningen | van | boijmans | depot",38],[38,"roof | rooftop | terrace | rooftopview | silveropening",36],[39,"esc2021 | mvrdv | depotboijmansvanbeuningen | walkaroundtown | mvrdviz",36],[40,"depotrotterdam | madrettor | dec | letyourhairdown | nearfocus",36],[41,"fujifilm | olympus | fujifilmnederland | filmisnotdead | ishootfilm",36],[42,"photography | mirrorplanet | beuningen | van | boijmans",36],[43,"congradulations | mvrdv | helped | realized | worked",35],[44,"usergrutter | depicted | their | user | visualized",35],[45,"mb | rotterdam | smile | mycityrotterdaminmirrorssummertimeeveningwalk | continuation",35],[46,"09112021 | 28112021 | luukenmariska | luukendaughters | luukeningridinrotterdam",34],[47,"boijmansdepot | boijmansvanbeuningenboijmansdepotrotterdamrottergramrott ...

# %% [markdown]
# Topics over time
# **Result**: The only real spike is during the Eurovision Song Contest, otherwise the topics are fairly stable (barring the silver opening and inauguration)

# %%
timestamps = df.index.to_list()
topics_over_time = model.topics_over_time(texts, topics, timestamps, nr_bins=10)
model.visualize_topics_over_time(topics_over_time, top_n_topics=6)
# Out:
# 10it [00:01,  5.00it/s]
# <div>                            <div id="b0dd0315-9358-4ed5-aa81-54fbe09b1e32" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0dd0315-9358-4ed5-aa81-54fbe09b1e32")) {                    Plotly.newPlot(                        "b0dd0315-9358-4ed5-aa81-54fbe09b1e32",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: bling, caesardonna, caesar, caesaruomo, welcomes","<b>Topic 0</b><br>Words: caesardonna, caesar, caesaruomo, welcomes, uomo","<b>Topic 0</b><br>Words: caesardonna, caesar, caesaruomo, welcomes, uomo","<b>Topic 0</b><br>Words: rather, rdam, caesaruomo, caesar, caesardonna","<b>Topic 0</b><br>Words: went, really, through, so, caesar","<b>Topic 0</b><br>Words: caesardonna, caesar, caesaruomo, welcomes, uomo","<b>Topic 0</b><br>Words: lol, round, about, caesar, caesardonna","<b>Topic 0</b><br>Words: unedited, imposing, caesardonna, caesaruomo, caesar","<b>Topic 0</b><br>Words: caesardonna, caesar, caesaruomo, welcomes, uomo","<b>Topic 0</b><br>Words: caesar, caesardonna, caesaruomo, welcomes, donna"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_caesar_caesardonna_caesaruomo_welcomes","type":"scatter","x":["2019-12-31T21:03:09.446000","2020-03-14T15:03:54.400000","2020-05-26T15:33:09.800000","2020-08-07T16:02:25.200000","2020-10-19T16:31:40.600000","2020-12-31T17:00:56","2021-03-14T17:30:11.400000","2021-05-26T17:59:26.800000","2021-08-07T18:28:42.200000","2021-10-19T18:57:57.600000"],"y":[3,7,33,65,25,26,16,30,27,286]},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: mirror, reflection, wall, instawalk024, insta024","<b>Topic 1</b><br>Words: mirror, seven, mirrors, reflections, f7d","<b>Topic 1</b><br>Words: mirror, reflection, reflections, wall, mirrors","<b>Topic 1</b><br>Words: mirror, reflection, mirrors, reflections, wall","<b>Topic 1</b><br>Words: mirror, reflections, reflection, wall, mirrors","<b>Topic 1</b><br>Words: mirror, reflection, wall, mirrors, snow","<b>Topic 1</b><br>Words: reflection, mirror, wolkenluchten, mirrors, piece","<b>Topic 1</b><br>Words: mirror, reflections, reflection, infinity, mirrors","<b>Topic 1</b><br>Words: mirror, reflection, reflections, wall, glass","<b>Topic 1</b><br>Words: mirror, reflection, wall, reflections, mirrors"],"marker":{"color":"#56B4E9"},"mode":"lines","name":"1_mirror_reflection_reflections_wall","type":"scatter","x":["2019-12-31T21:03:09.446000","2020-03-14T15:03:54.400000","2020-05-26T15:33:09.800000","2020-08-07T16:02:25.200000","2020-10-19T16:31:40.600000","2020-12-31T17:00:56","2021-03-14T17:30:11.400000","2021-05-26T17:59:26.800000","2021-08-07T18:28:42.200000","2021-10-19T18:57:57.600000"],"y":[14,9,32,42,32,39,15,11,26,55]},{"hoverinfo":"text","hovertext":["<b>Topic 2</b><br>Words: facility, storage, conservation, eg, adrianus","<b>Topic 2</b><br>Words: will, collection, activities, resume, worlds","<b>Topic 2</b><br>Words: first, museums, will, storage, public","<b>Topic 2</b><br>Words: collection, public, will, storage, accessible","<b>Topic 2</b><br>Words: museums, works, the, first, of","<b>Topic 2</b><br>Words: access, browse, complete, offers, world","<b>Topic 2</b><br>Words: collection, first, access, the, public","<b>Topic 2</b><br>Words: collection, will, the, storage, of","<b>Topic 2</b><br>Words: will, works, storage, collection, first","<b>Topic 2</b><br>Words: storage, first, the, collection, art"],"marker":{"color":"#009E73"},"mode":"lines","name":"2_storage_collection_first_the","type":"scatter","x":["2019-12-31T21:03:09.446000","2020-03-14T15:03:54.400000","2020-05-26T15:33:09.800000","2020-08-07T16:02:25.200000","2020-10-19T16:31:40.600000","2020-12-31T17:00:56","2021-03-14T17:30:11.400000","2021-05-26T17:59:26.800000","2021-08-07T18:28:42.200000","2021 ...

# %% [markdown]
# Topic Model for each actor group

# %%
# topic_output_folder_bertopic = "results/topic_modeling/bertopic"
# os.makedirs(topic_output_folder_bertopic, exist_ok=True)

# No pre-processing needed:
# https://maartengr.github.io/BERTopic/faq.html

for micro_role in micro_roles:
    print("-----{}-------".format(micro_role))
    # fpath_fig = os.path.join(topic_output_folder_bertopic, "bert_{}.png".format(micro_role))
    # fpath_csv = os.path.join(topic_output_folder_bertopic, "bert_{}.csv".format(micro_role))

    slice = df[df["MicroRole"] == micro_role]

    """"
    tweaks:
    remove stopwords
    remove mentions
    diversity=0.5
    hdbscan: min_cluster_size=3,  min_samples=5, for Individuals: default params
    """
    texts = slice["caption_en_head_nostopwords"].apply(remove_mentions)

    if micro_role == "Individual":
        hdbscan_model = HDBSCAN(min_cluster_size=10)
    else:
        hdbscan_model = HDBSCAN(min_cluster_size=3, min_samples=5)

    # default umap model with random state for reproducibility
    umap_model = UMAP(n_neighbors=15, n_components=5,
                      min_dist=0.0, metric='cosine', random_state=42)

    model = BERTopic(verbose=True, diversity=0.5, hdbscan_model=hdbscan_model, umap_model=umap_model)
    topics, probabilities = model.fit_transform(texts)
    try:
        fig = model.visualize_barchart(top_n_topics=20)
        fig.show()
        # fig.write_image(fpath_fig)
    except ValueError:
        pass

    topwords_df = bertopic_topics_to_df(model, max_topics=20)
    # topwords_df.to_csv(fpath_csv, index=False)

    # print(topwords_df.to_string())
# Out:
# -----Individual-------
# Batches:   0%|          | 0/231 [00:00<?, ?it/s]
# 2022-12-26 16:17:09,426 - BERTopic - Transformed documents to Embeddings
# 2022-12-26 16:17:23,999 - BERTopic - Reduced dimensionality with UMAP
# 2022-12-26 16:17:24,255 - BERTopic - Clustered UMAP embeddings with HDBSCAN
# <div>                            <div id="97ef426b-b6d4-4bf7-89b5-b3f15c9d9f80" class="plotly-graph-div" style="height:1250px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97ef426b-b6d4-4bf7-89b5-b3f15c9d9f80")) {                    Plotly.newPlot(                        "97ef426b-b6d4-4bf7-89b5-b3f15c9d9f80",                        [{"marker":{"color":"#D55E00"},"orientation":"h","type":"bar","x":[0.008795399795725963,0.010053642056897258,0.01231355971401635,0.03448114344973338,0.04543187562645539],"xaxis":"x","y":["esc2021  ","songcontest  ","flags  ","countdown  ","contest  "],"yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","type":"bar","x":[0.005932780247627334,0.006029095890975187,0.007284153849704148,0.008170379536178251,0.015504165416279818],"xaxis":"x2","y":["renovation  ","museums  ","park  ","kisters  ","van  "],"yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","type":"bar","x":[0.018232818830254485,0.019485324414792057,0.028908987700182364,0.029082663869462778,0.03189442751417875],"xaxis":"x3","y":["rotterdamalwayson  ","weekendsinrotterdam  ","loverotterdam  ","rotterdamhotspots  ","rottergram  "],"yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","type":"bar","x":[0.021357430103437342,0.021357430103437342,0.021357430103437342,0.035216873674675755,0.05259220110717293],"xaxis":"x4","y":["semifinal  ","irun  ","continuation  ","lady  ","rotterdam  "],"yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","type":"bar","x":[0.01480688236176118,0.020594113043401845,0.022272543127261134,0.02475155667946401,0.026384140035991988],"xaxis":"x5","y":["mary  ","increases  ","reading  ","meaning  ","art  "],"yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","type":"bar","x":[0.007583153198087442,0.007673847596683786,0.00847574228290371,0.008828781802051088,0.010359935629959191],"xaxis":"x6","y":["museums  ","collections  ","public  ","151000  ","visitors  "],"yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","type":"bar","x":[0.010835669462028855,0.012545554696554193,0.016355421186745295,0.021110650693144585,0.02937748519974929],"xaxis":"x7","y":["boymans  ","construction  ","rotterdam  ","gates  ","park  "],"yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","type":"bar","x":[0.010543397586813384,0.010803127050120103,0.010803127050120103,0.011736114847864477,0.012890063738496356],"xaxis":"x8","y":["havent  ","decided  ","exploring  ","tourist  ","lovely  "],"yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","type":"bar","x":[0.026203233572284473,0.026203233572284473,0.03246905581504698,0.034072935343106465,0.037431489884483256],"xaxis":"x9","y":["janvanmunster  ","citydog  ","left  ","depotmuseumboijmansvanbeuningen  ","expensive  "],"yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","type":"bar","x":[0.02180548807763533,0.026937188737594663,0.027631074955114878,0.038777464646710225,0.1367875888475057],"xaxis":"x10","y":["symmetric  ","looking  ","seven  ","dizzy  ","wall  "],"yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","type":"bar","x":[0.0716824090828012,0.0716824090828012,0.0716824090828012,0.0716824090828012,0.0891310138674303],"xaxis":"x11","y":["berman  ","treasurer  ","wording  ","portra  ","depot  "],"yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","type":"bar","x":[0.0789413872177684,0.0789413872177684,0.10172042183212987,0.10891475254311685,0.1432694027124546],"xaxis":"x12","y":["b2b  ","balde7  ","010  ","mom  ","hey  "],"yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","type":"bar","x":[0.019549747931673054,0.019549747931673054,0.020684448233651554,0.02430845832748099,0.04210005362892283],"xaxis":"x13","y":["beaks  ","constructionsite  ","opening  ","depot  ","boijmans  "],"yaxis": ...
# -----Enterprise-------
# Batches:   0%|          | 0/17 [00:00<?, ?it/s]
# 2022-12-26 16:17:36,311 - BERTopic - Transformed documents to Embeddings
# 2022-12-26 16:17:38,153 - BERTopic - Reduced dimensionality with UMAP
# 2022-12-26 16:17:38,177 - BERTopic - Clustered UMAP embeddings with HDBSCAN
# <div>                            <div id="5019fd5d-f835-4d29-a62a-9b45370e4d7c" class="plotly-graph-div" style="height:1250px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5019fd5d-f835-4d29-a62a-9b45370e4d7c")) {                    Plotly.newPlot(                        "5019fd5d-f835-4d29-a62a-9b45370e4d7c",                        [{"marker":{"color":"#D55E00"},"orientation":"h","type":"bar","x":[0.020923066744084024,0.02436439939121411,0.024438013757581145,0.026669793102245522,0.03140078642845019],"xaxis":"x","y":["van  ","museum  ","gers  ","boijmans  ","depot  "],"yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","type":"bar","x":[0.031593352583357104,0.03508187655992814,0.036193665402416496,0.03728210743073542,0.037690540993703246],"xaxis":"x2","y":["twitter  ","igdiscoverholland  ","rotterdamhotspots  ","rotterdamgallery  ","loverotterdam  "],"yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","type":"bar","x":[0.027640869091211613,0.03150282330906052,0.033405965784457224,0.034551086364014515,0.037448915227811345],"xaxis":"x3","y":["enjoy  ","skylge  ","summer  ","lets  ","guests  "],"yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","type":"bar","x":[0.06752143880681442,0.0795934164135998,0.08463576456163877,0.08463576456163877,0.09176263011008307],"xaxis":"x4","y":["people  ","visiting  ","2019  ","shop  ","sustainable  "],"yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","type":"bar","x":[0.046396020332872205,0.04719978088098545,0.06084273862976369,0.09005983571133491,0.09176816991297056],"xaxis":"x5","y":["great  ","city  ","building  ","depot  ","shot  "],"yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","type":"bar","x":[0.028596931263777832,0.029546771426002764,0.039865884616008734,0.03989622279865319,0.04811739603735384],"xaxis":"x6","y":["rotterdam  ","boijmans  ","depot  ","van  ","museum  "],"yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","type":"bar","x":[0.02985757665928219,0.02998329713923303,0.03135063168091042,0.03637135355257364,0.04097706363095595],"xaxis":"x7","y":["van  ","2021  ","edition  ","inkjet  ","museum  "],"yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","type":"bar","x":[0.07122062004900331,0.07217388835456462,0.13062218053690708,0.16668354583587514,0.16668354583587514],"xaxis":"x8","y":["museum  ","rotterdam  ","mvrdv  ","pot  ","maas  "],"yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","type":"bar","x":[0.10206849506828153,0.1143917367941514,0.1366352993453991,0.1448740655834067,0.14803543530807647],"xaxis":"x9","y":["open  ","museums  ","boymansvanbeuningen  ","assignment  ","mug  "],"yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","type":"bar","x":[0.08557401245620891,0.13472459708147017,0.1568990089940812,0.1641424518526491,0.23385443853682036],"xaxis":"x10","y":["glass  ","model  ","photographer  ","reflections  ","pieces  "],"yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","type":"bar","x":[0.12432168950628067,0.14292273799202881,0.14292273799202881,0.14292273799202881,0.1490908281179563],"xaxis":"x11","y":["rotterdamcitymodernbuilding  ","architecturepornspiegelbeeld  ","architectureloversmirrorshot  ","architecturehunter  ","architecture  "],"yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","type":"bar","x":[0.054033002234266554,0.05858292204768015,0.07248586642400094,0.1322143224008574,0.19262391417557254],"xaxis":"x12","y":["growing  ","betula  ","birch  ","trees  ","roof  "],"yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","type":"bar","x":[0.03534434809104178,0.03605222385041618,0.039135023885532985,0.049554027849789406,0.049554027849789406],"xaxis":"x13","y":["atrium  ","artworks  ","151000  ","maze  ","idea  "],"yaxis":"y13"},{"marker" ...
# -----Affiliated enterprise-------
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# 2022-12-26 16:17:46,996 - BERTopic - Transformed documents to Embeddings
# 2022-12-26 16:17:47,972 - BERTopic - Reduced dimensionality with UMAP
# 2022-12-26 16:17:47,979 - BERTopic - Clustered UMAP embeddings with HDBSCAN
# <div>                            <div id="d0c009f1-c340-4ce4-9271-211fbf5afe3b" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0c009f1-c340-4ce4-9271-211fbf5afe3b")) {                    Plotly.newPlot(                        "d0c009f1-c340-4ce4-9271-211fbf5afe3b",                        [{"marker":{"color":"#D55E00"},"orientation":"h","type":"bar","x":[0.05150578205872335,0.056031753498183165,0.06862565192720665,0.0903101341503407,0.09207633943648445],"xaxis":"x","y":["rotterdam  ","boijmans  ","museum  ","depot  ","van  "],"yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","type":"bar","x":[0.04507282494717729,0.046610560875314004,0.04782578637180738,0.053648579914982605,0.060996844760014164],"xaxis":"x2","y":["van  ","skaters  ","building  ","museumpark  ","depot  "],"yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","type":"bar","x":[0.07727666036998067,0.08426137739955666,0.09047294219168885,0.10272837048450942,0.12028860191808866],"xaxis":"x3","y":["open  ","boijmans  ","van  ","beuningen  ","depot  "],"yaxis":"y3"}],                        {"annotations":[{"font":{"size":16},"showarrow":false,"text":"Topic 1","x":0.0875,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Topic -1","x":0.36250000000000004,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Topic 2","x":0.6375000000000001,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"}],"height":325.0,"hoverlabel":{"bgcolor":"white","font":{"family":"Rockwell","size":16}},"showlegend":false,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0 ...
# -----Public institution-------
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2022-12-26 16:17:56,067 - BERTopic - Transformed documents to Embeddings
# 2022-12-26 16:17:56,873 - BERTopic - Reduced dimensionality with UMAP
# 2022-12-26 16:17:56,883 - BERTopic - Clustered UMAP embeddings with HDBSCAN
# <div>                            <div id="4474ca4b-4af2-4b92-8753-04724fcd43a6" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4474ca4b-4af2-4b92-8753-04724fcd43a6")) {                    Plotly.newPlot(                        "4474ca4b-4af2-4b92-8753-04724fcd43a6",                        [{"marker":{"color":"#D55E00"},"orientation":"h","type":"bar","x":[0.031683270203783136,0.03583624685423156,0.04819626941038163,0.05517101152009233,0.060247374743347216],"xaxis":"x","y":["boijmans  ","work  ","see  ","reflection  ","depot  "],"yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","type":"bar","x":[0.08357498833016183,0.08383568245656564,0.0844250293439315,0.0863316071556176,0.08665751582522828],"xaxis":"x2","y":["doors  ","van  ","beuningen  ","depot  ","boijmans  "],"yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","type":"bar","x":[0.03589489689736198,0.04446889798875754,0.07118318054722793,0.0712425996950692,0.10644960338881526],"xaxis":"x3","y":["video  ","morning  ","rotterdam  ","countdown  ","eurovision  "],"yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","type":"bar","x":[0.10552236929225776,0.10552236929225776,0.10552236929225776,0.10552236929225776,0.15584869991815326],"xaxis":"x4","y":["followers  ","wonder  ","conversations  ","colorless  ","happy  "],"yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","type":"bar","x":[0.04751241263053014,0.05502997557181856,0.09348522952687416,0.0983046037684405,0.1039754577856561],"xaxis":"x5","y":["weekend  ","popup  ","bag  ","depot  ","opening  "],"yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","type":"bar","x":[0.03426903490146653,0.036187594068658735,0.03704443424589911,0.04556462977363054,0.06396071407312942],"xaxis":"x6","y":["depot  ","garden  ","art  ","day  ","rotterdam  "],"yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","type":"bar","x":[0.08106566293913056,0.08108567945399955,0.08328756211316296,0.08757009078958776,0.11469132636276519],"xaxis":"x7","y":["apply  ","rotterdam  ","museum  ","heart  ","cultural  "],"yaxis":"y7"}],                        {"annotations":[{"font":{"size":16},"showarrow":false,"text":"Topic 0","x":0.0875,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Topic 1","x":0.36250000000000004,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Topic 2","x":0.6375000000000001,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Topic 3","x":0.9125,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Topic 4","x":0.0875,"xanchor":"center","xref":"paper","y":0.4,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Topic 5","x":0.36250000000000004,"xanchor":"center","xref":"paper","y":0.4,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Topic 6","x":0.6375000000000001,"xanchor":"center","xref":"paper","y":0.4,"yanchor":"bottom","yref":"paper"}],"height":500,"hoverlabel":{"bgcolor":"white","font":{"family":"Rockwell","size":16}},"showlegend":false,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startl ...
# -----Private tourism outlet-------
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# 2022-12-26 16:18:05,048 - BERTopic - Transformed documents to Embeddings
# 2022-12-26 16:18:05,772 - BERTopic - Reduced dimensionality with UMAP
# 2022-12-26 16:18:05,778 - BERTopic - Clustered UMAP embeddings with HDBSCAN
# <div>                            <div id="d0a6a613-78b0-410b-afa9-f07f301d8965" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0a6a613-78b0-410b-afa9-f07f301d8965")) {                    Plotly.newPlot(                        "d0a6a613-78b0-410b-afa9-f07f301d8965",                        [{"marker":{"color":"#D55E00"},"orientation":"h","type":"bar","x":[0.03588667950071013,0.04240350866014906,0.04828868434156996,0.05451879684876308,0.05717371446462891],"xaxis":"x","y":["fanatics  ","fun  ","rotterdam  ","coronaproof  ","also  "],"yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","type":"bar","x":[0.10486746327298754,0.10486746327298754,0.12047073117851799,0.1263328773294849,0.1658540217015196],"xaxis":"x2","y":["readyand  ","volvo  ","tourguide  ","depot  ","roll  "],"yaxis":"y2"}],                        {"annotations":[{"font":{"size":16},"showarrow":false,"text":"Topic 1","x":0.0875,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Topic -1","x":0.36250000000000004,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"}],"height":325.0,"hoverlabel":{"bgcolor":"white","font":{"family":"Rockwell","size":16}},"showlegend":false,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"# ...
# -----Depot Boijmans designer-------
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# 2022-12-26 16:18:13,767 - BERTopic - Transformed documents to Embeddings
# 2022-12-26 16:18:14,506 - BERTopic - Reduced dimensionality with UMAP
# 2022-12-26 16:18:14,513 - BERTopic - Clustered UMAP embeddings with HDBSCAN
# <div>                            <div id="92de339b-245a-4c2d-8601-63529271f221" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92de339b-245a-4c2d-8601-63529271f221")) {                    Plotly.newPlot(                        "92de339b-245a-4c2d-8601-63529271f221",                        [{"marker":{"color":"#D55E00"},"orientation":"h","type":"bar","x":[0.05863551299938243,0.060649913477681894,0.06141432445479182,0.06596047842225479,0.07037114971179581],"xaxis":"x","y":["depotboijmansvanbeuningen  ","van  ","showcases  ","artdepotlovers  ","fineartstorage  "],"yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","type":"bar","x":[0.07492315549921087,0.07704734888430109,0.07811693370922984,0.07951213847420262,0.08134972294750338],"xaxis":"x2","y":["design  ","depot  ","restaurant  ","renilde  ","concrete  "],"yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","type":"bar","x":[0.061423203177939374,0.07449140744870213,0.0949080101054206,0.1121640119427698,0.13719834932906247],"xaxis":"x3","y":["boijmans  ","art  ","concrete  ","accessible  ","depot  "],"yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","type":"bar","x":[0.03804212019599913,0.043760424170512534,0.043760424170512534,0.05355823656306928,0.06112971577813424],"xaxis":"x4","y":["museum  ","spaces  ","roof  ","depot  ","climate  "],"yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","type":"bar","x":[0.04822042503657672,0.050930001300771605,0.06109112757627928,0.065518083389802,0.08961032757279795],"xaxis":"x5","y":["van  ","complete  ","rotterdam  ","boijmans  ","museum  "],"yaxis":"y5"}],                        {"annotations":[{"font":{"size":16},"showarrow":false,"text":"Topic 0","x":0.0875,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Topic 1","x":0.36250000000000004,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Topic 2","x":0.6375000000000001,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Topic 3","x":0.9125,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Topic 4","x":0.0875,"xanchor":"center","xref":"paper","y":0.4,"yanchor":"bottom","yref":"paper"}],"height":500,"hoverlabel":{"bgcolor":"white","font":{"family":"Rockwell","size":16}},"showlegend":false,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11 ...

# %% [markdown]
# **Result:**
# The topic models for actor groups with few posts are very small and extremely difficult to compare to other groups qualitatively.
# This issue arises because BERToptic needs ~1000 documents to produce coherent topic models as indicated by the author of BERTopic.
# Another issue was that named entities such as 'Depot' 'Boijmans' 'Van' 'Beuningen' dominated the topic model though removing them did not make the topic model more coherent.
#
# Other topic modeling algos like NMF and LDA were also considered but could not provide easily interpretable results either.
# Though I'm no expert on natural language processing and it's possible that with a different topic modeling algo or better pre-processing the results could be improved.
#
#
#
# For a quantitative comparison of topics discussed by the actor groups we turn to a more simple method of word frequency counting.

# %% [markdown]
# # Topic Analysis with Word Counting

# %% [markdown]
# Pre-processing: part-of-speech tagging and dependency parsing
# Analysis: we are looking at top:
# - nouns -> not that insightful
# - adjectives -> missing some context, i.e. what the adjective refers to
# - adjective-noun combinations -> solving the context problem from above

# %%
def remove_punctuation(text, punctuation_str):
    text = "".join([char for char in text if char not in punctuation_str])
    return text

def spacy_pos_tag(text):
    pos = []
    doc = nlp(text)
    for token in doc:
        pos.append((token.text, token.pos_))
    return pos

caption_cleaned = df["caption_en_head"].apply(lambda s: remove_punctuation(s, punctuation).lower())
# POS tagging
df["caption_en_pos"] = caption_cleaned.progress_apply(spacy_pos_tag)

# Creating spacy NLP objects for dependency parsing
df["nlp_text"] = sentences = df["caption_en_head"].apply(lambda s: remove_mentions(s).lower())
df["nlp"] = df["nlp_text"].progress_apply(nlp)
# Out:
# 100%|██████████| 8228/8228 [00:40<00:00, 200.77it/s]
# 100%|██████████| 8228/8228 [00:44<00:00, 184.66it/s]

# %%
def get_top_pos(pos_corpus, target_pos):
    """
    Finds all words in a POS-tagged corpus that match the target POS
    :param pos_corpus: list of list of  ("word, [POS TAG]) tuples
    :param target_pos: https://universaldependencies.org/u/pos/
    :return: list of words that match the POS
    """
    all_words = []
    for pos_list in pos_corpus:
        for tup in pos_list:
            if tup[1] == target_pos:
                all_words.append(tup[0])
    return all_words


def get_pos_count_df(df, group_column, target_pos, text_column="caption_en_pos"):
    """
    :param df: dataframe
    :param group_column: column name with different groups by which the results are split by
    :param target_pos: https://universaldependencies.org/u/pos/
    :param text_column: column with list of ("word, [POS TAG]) tuples
    :return: dataframe with top 20 most common words that match the POS per group
    """
    df_pos = pd.DataFrame()
    for tag in df[group_column].unique():
        slice = df[df[group_column] == tag]
        words = get_top_pos(slice[text_column], target_pos=target_pos)

        ser = pd.Series(words).value_counts().reset_index()
        ser.columns = [tag, tag + "_count"]

        df_pos = pd.concat([df_pos, ser[:20]], axis=1)
    return df_pos


def get_top_adjnouns(docs):
    """
    Gets all ADJ-NOUN pairs in a corpus (docs) by parsing the dependency tree
    :param docs: list of spacy nlp() objects
    """
    collected = []
    for doc in docs:
        for token in doc:
            pos = token.pos_
            if pos == "ADJ":
                head = token
                for i in range(len(doc)):  # avoid infinite cycles due to circiular dependenceis
                    head = head.head
                    if (str(head.dep_) == str(head.text)) or str(head.pos_) == "NOUN":
                        break
                if str(head.pos_) == "NOUN":
                    collected.append("{} {}".format(token.text, head.text))
    return collected


def get_adjnoun_count_df(df, group_column, docs_column):
    """
    :param df: dataframe
    :param group_column: column name with different groups by which the results are split by
    :param docs_column: column that contains spacy NLP objects
    :return: dataframe with top 20 most common ADJ-NOUN combinations
    """
    df_collecter = pd.DataFrame()
    for tag in df[group_column].unique():
        slice = df[df[group_column] == tag]

        docs = list(filter(lambda s: len(s) > 0, slice[docs_column]))

        words = get_top_adjnouns(docs)
        # lazy named entity removal
        words = list(filter(lambda w: w not in ["️marieke diemen", "winy maas"], words))

        ser = pd.Series(words).value_counts().reset_index()
        ser.columns = [tag, tag + "_count"]

        df_collecter = pd.concat([df_collecter, ser[:20]], axis=1)

    return df_collecter


def format_bracket(val1, val2, percent=False, round_to=1, stdev=False):
    """
    Formats as 'val1 (val2)' or 'val1 (val2%)'
    """
    if round_to == 0:
        round_to = None
    if percent:
        str2 = " ({:.1%})"
    elif stdev:
        str2 = " (±{:,})"
        val2 = round(val2, round_to)
    else:
        str2 = " ({:,})"
        val2 = round(val2, round_to)

    return "{:,}".format(round(val1, round_to)) + str2.format(val2)

def format_count_df(df):
    count_df = df.copy()
    # iterate through uneven columns
    for i in range(1, len(count_df.columns), 2):
        count_df.iloc[:, i] = count_df.iloc[:, i].apply(
            lambda v: format_bracket(v, v / count_df.iloc[:, i].sum(), percent=True))
    return count_df

# %% [markdown]
# Top nouns

# %%
res = get_pos_count_df(df, "MacroRole", "NOUN")
format_count_df(res)
# Out:
#                       Private  Private_count      Public Public_count
# 0                       depot  4,121 (24.7%)       depot  364 (22.7%)
# 1                        user  2,432 (14.6%)        user  237 (14.8%)
# 2                    boijmans   1,525 (9.1%)    boijmans   115 (7.2%)
# 3                      museum   1,508 (9.0%)         art   113 (7.0%)
# 4                         art   1,471 (8.8%)      museum   103 (6.4%)
# 5                    building     974 (5.8%)  collection    78 (4.9%)
# 6                        city     549 (3.3%)    building    71 (4.4%)
# 7                  collection     435 (2.6%)         bag    69 (4.3%)
# 8   depotboijmansvanbeuningen     384 (2.3%)     opening    61 (3.8%)
# 9                     opening     363 (2.2%)    shopping    56 (3.5%)
# 10               architecture     361 (2.2%)       doors    46 (2.9%)
# 11                  beuningen     338 (2.0%)    visitors    39 (2.4%)
# 12                      world     316 (1.9%)        days    33 (2.1%)
# 13                        day     307 (1.8%)       world    32 (2.0%)
# 14                    storage     290 (1.7%)        city    32 (2.0%)
# 15                      today     274 (1.6%)      design    32 (2.0%)
# 16                      mvrdv     271 (1.6%)  museumpark    31 (1.9%)
# 17                       time     266 (1.6%)      mirror    31 (1.9%)
# 18                       view     265 (1.6%)         day    30 (1.9%)
# 19                      works     254 (1.5%)       glass    30 (1.9%)

# %% [markdown]
# Top adjectives

# %%
res = get_pos_count_df(df, "MacroRole", "ADJ")
format_count_df(res)
# Out:
#        Private Private_count      Public Public_count
# 0          new   864 (18.6%)         new  106 (21.1%)
# 1    beautiful   636 (13.7%)  accessible    48 (9.5%)
# 2        first    351 (7.5%)       first    35 (7.0%)
# 3         more    325 (7.0%)        more    32 (6.4%)
# 4   accessible    285 (6.1%)        open    26 (5.2%)
# 5         open    235 (5.0%)      public    24 (4.8%)
# 6         nice    230 (4.9%)    complete    22 (4.4%)
# 7        great    211 (4.5%)     special    20 (4.0%)
# 8         last    203 (4.4%)        next    19 (3.8%)
# 9       public    166 (3.6%)        last    19 (3.8%)
# 10        cool    158 (3.4%)       large    19 (3.8%)
# 11     special    136 (2.9%)   beautiful    18 (3.6%)
# 12       other    125 (2.7%)   available    18 (3.6%)
# 13   different    123 (2.6%)   different    17 (3.4%)
# 14     amazing    111 (2.4%)       happy    15 (3.0%)
# 15  impressive    110 (2.4%)      unique    15 (3.0%)
# 16        able    101 (2.2%)        many    14 (2.8%)
# 17       happy    100 (2.1%)       other    12 (2.4%)
# 18  reflective     93 (2.0%)         own    12 (2.4%)
# 19        good     92 (2.0%)       empty    12 (2.4%)

# %% [markdown]
# Top adjective-noun combinations

# %%
adjnoun = get_adjnoun_count_df(df, "MacroRole", "nlp")
format_count_df(adjnoun)
# Out:
#                 Private Private_count               Public Public_count
# 0             new depot   268 (19.9%)          first depot   28 (12.7%)
# 1           first depot   167 (12.4%)              new bag   26 (11.8%)
# 2      accessible depot    127 (9.4%)     accessible depot   24 (10.9%)
# 3        first facility     85 (6.3%)             new icon    13 (5.9%)
# 4          new building     81 (6.0%)  complete collection    12 (5.5%)
# 5    beautiful building     79 (5.9%)             new type    11 (5.0%)
# 6   complete collection     63 (4.7%)          sturdy room    10 (4.5%)
# 7     entire collection     60 (4.5%)            new depot    10 (4.5%)
# 8              new icon     54 (4.0%)      accessible room    10 (4.5%)
# 9   accessible facility     50 (3.7%)     official opening     9 (4.1%)
# 10      beautiful depot     39 (2.9%)             new home     8 (3.6%)
# 11           first time     36 (2.7%)   special experience     7 (3.2%)
# 12           more works     34 (2.5%)            more info     7 (3.2%)
# 13         more objects     31 (2.3%)           first time     7 (3.2%)
# 14            last week     31 (2.3%)            extra day     7 (3.2%)
# 15       beautiful view     30 (2.2%)     super experience     7 (3.2%)
# 16      iconic building     29 (2.2%)            top floor     6 (2.7%)
# 17            next year     28 (2.1%)            next year     6 (2.7%)
# 18           public art     27 (2.0%)      iconic building     6 (2.7%)
# 19     official opening     26 (1.9%)        many requests     6 (2.7%)

# %% [markdown]
# # Sentiment Analysis

# %%
def remove_newlines(text, replace_with=""):
    return text.replace('\n', replace_with)

def remove_hashtag_mention_symbols(text):
    """
    removes @ and # from text while leaving the words behind those symbols
    Example: I went to the #mall -> I went to the mall
    """
    text = re.sub("#", "", text)
    text = re.sub("@", "", text)
    return text

def preprocess_for_sentiments(text):
    text = text.lower()
    # text = convert_emojis_to_word(text, preface="") # TODO: add back in
    text = remove_newlines(text, replace_with=" ")
    text = remove_hashtag_mention_symbols(text)
    return text

# %%
# https://spacy.io/universe/project/spacy-textblob
"""
The polarity score is a float within the range [-1.0, 1.0].
The subjectivity is a float within the range [0.0, 1.0] where 0.0 is very objective and 1.0 is very subjective.
"""

sentiment_texts = []
for text in tqdm(df["caption_en_head"]):
    sentiment_texts.append(preprocess_for_sentiments(text))
df["sentiment_text"] = sentiment_texts

sentiments = []
subjectivities = []
assessments = []

for text in tqdm(df["sentiment_text"]):
    doc = nlp(text)
    sentiments.append(doc._.polarity)
    subjectivities.append(doc._.subjectivity)
    assessments.append(doc._.assessments)

df["sentiment"] = sentiments
df["subjectivity"] = subjectivities
df["sent_assessment"] = assessments
# Out:
# 100%|██████████| 8228/8228 [00:00<00:00, 249355.01it/s]
# 100%|██████████| 8228/8228 [00:44<00:00, 184.96it/s]

# %% [markdown]
# Top positive/negative sentiment captions

# %%
df[["sentiment_text", "sentiment", "subjectivity", "sent_assessment"]].sort_values("sentiment", ascending=True)
# Out:
#                                                         sentiment_text  \
# timestamp
# 2021-03-26 10:56:08  rotterdam's newest spaceship   the boijmans va...
# 2021-12-16 07:17:15                          insane pivot doors in the
# 2021-12-03 20:06:34  terrible weather all week but nothing can ruin...
# 2021-02-26 13:14:26  my jacket says it, so s💜m🙃i💜l🙂e💜  rokjesdag ma...
# 2020-08-29 20:17:37  🎶 jump around! jump around! jump around! jump ...
# ...                                                                ...
# 2020-07-01 14:02:33  reflection inception depot boijmansvanbeuninge...
# 2021-04-06 09:01:18  even with a hailstorm, the depot is beautiful....
# 2021-12-03 22:54:26                              something incredible!
# 2021-12-17 12:21:47  “did you see that dude? yes, isn't it?!?” deli...
# 2021-02-21 14:29:23  what a beautiful depot!  depotrotterdam010boym...
#
#                      sentiment  subjectivity  \
# timestamp
# 2021-03-26 10:56:08  -1.000000      1.000000
# 2021-12-16 07:17:15  -1.000000      1.000000
# 2021-12-03 20:06:34  -1.000000      1.000000
# 2021-02-26 13:14:26  -0.780000      1.000000
# 2020-08-29 20:17:37  -0.741747      0.288889
# ...                        ...           ...
# 2020-07-01 14:02:33   1.000000      1.000000
# 2021-04-06 09:01:18   1.000000      1.000000
# 2021-12-03 22:54:26   1.000000      0.900000
# 2021-12-17 12:21:47   1.000000      1.000000
# 2021-02-21 14:29:23   1.000000      1.000000
#
#                                                        sent_assessment
# timestamp
# 2021-03-26 10:56:08                      [([insane], -1.0, 1.0, None)]
# 2021-12-16 07:17:15                      [([insane], -1.0, 1.0, None)]
# 2021-12-03 20:06:34                    [([terrible], -1.0, 1.0, None)]
# 2021-02-26 13:14:26                 [([very, cold], -0.78, 1.0, None)]
# 2020-08-29 20:17:37  [([down, !, !, !, !, !, !, !], -0.741746690538...
# ...                                                                ...
# 2020-07-01 14:02:33                 [([breathtaking], 1.0, 1.0, None)]
# 2021-04-06 09:01:18                 [([beautiful, !], 1.0, 1.0, None)]
# 2021-12-03 22:54:26                [([incredible, !], 1.0, 0.9, None)]
# 2021-12-17 12:21:47  [([delicious], 1.0, 1.0, None), ([beautiful, !...
# 2021-02-21 14:29:23                 [([beautiful, !], 1.0, 1.0, None)]
#
# [8228 rows x 4 columns]

# %% [markdown]
# Looking at these captions, the sentiment analysis is easily distratced by certain keywords...

# %% [markdown]
# Top words for positive/negative sentiments

# %%
# os.makedirs("results/nlp_sentiment_analysis", exist_ok=True)
neg = df.sort_values("sentiment", ascending=True)[["sentiment_text", "sentiment", "subjectivity"]][:100]
# neg.to_csv("results/nlp_sentiment_analysis/top_negative.csv")

pos = df.sort_values("sentiment", ascending=False)[["sentiment_text", "sentiment", "subjectivity"]][:100]
# pos.to_csv("results/nlp_sentiment_analysis/top_positive.csv")

df_neg = df[df.index.isin(neg.index)]
df_neg["word"] = "word"
get_pos_count_df(df_neg, "word", "ADJ", text_column="caption_en_pos")
# Out:
#            word  word_count
# 0        broken          18
# 1          cold          10
# 2         crazy           8
# 3        mockup           4
# 4           bio           4
# 5          last           4
# 6    impossible           4
# 7         weird           3
# 8           new           3
# 9   complicated           2
# 10   continuous           2
# 11       random           2
# 12       insane           2
# 13        tough           2
# 14    rotterdam           2
# 15        sorry           2
# 16        empty           2
# 17         late           2
# 18          bad           2
# 19       little           2

# %%
df_pos = df[df.index.isin(pos.index)]
df_pos["word"] = "word"
get_pos_count_df(df_pos, "word", "ADJ", text_column="caption_en_pos")
# Out:
#           word  word_count
# 0    beautiful          30
# 1   impressive          21
# 2        happy           9
# 3        great           8
# 4    wonderful           7
# 5         best           6
# 6    delicious           3
# 7      awesome           3
# 8       easter           2
# 9    rotterdam           2
# 10     elusive           2
# 11     perfect           2
# 12      silver           2
# 13        nice           2
# 14        winy           1
# 15  happyhappy           1
# 16         own           1
# 17        good           1
# 18       macro           1
# 19   rooterdam           1

# %% [markdown]
# Average sentiment by actor group

# %%
df.groupby(["MacroRole"])["sentiment"].mean().round(2)
# Out:
# MacroRole
# Private    0.13
# Public     0.19
# Name: sentiment, dtype: float64

# %% [markdown]
# **Result**: Public actors write captions with slightly more positive sentiments. But the sentiment analysis is not so robust that this is a reliable finding

# %%
df.groupby(["MicroRole"])["sentiment"].mean().round(2)
# Out:
# MicroRole
# Affiliated enterprise      0.18
# Depot Boijmans designer    0.19
# Enterprise                 0.15
# Individual                 0.13
# Private tourism outlet     0.30
# Public institution         0.20
# Name: sentiment, dtype: float64
